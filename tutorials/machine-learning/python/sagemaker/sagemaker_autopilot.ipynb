# %%
# !pip install sagemaker pyexasol
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.45.0)
# Collecting pyexasol
#   Downloading pyexasol-0.20.0-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 1.6 MB/s  eta 0:00:01
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.19.5)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.7)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.1.5)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.7.0)
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (20.3.0)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.15.2)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (20.9)
# Requirement already satisfied: boto3>=1.16.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.17.99)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.4.2)
# Requirement already satisfied: botocore<1.21.0,>=1.20.99 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (1.20.99)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.99->boto3>=1.16.32->sagemaker) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.99->boto3>=1.16.32->sagemaker) (1.26.5)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker) (1.15.0)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.47.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyexasol) (0.59.0)
# Requirement already satisfied: rsa in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyexasol) (4.7.2)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2021.1)
# Requirement already satisfied: pox>=0.2.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.2.9)
# Requirement already satisfied: ppft>=1.6.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (1.6.6.3)
# Requirement already satisfied: dill>=0.3.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.3)
# Requirement already satisfied: multiprocess>=0.70.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.70.11.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from rsa->pyexasol) (0.4.8)
# Installing collected packages: pyexasol
# Successfully installed pyexasol-0.20.0
# WARNING: You are using pip version 21.1.2; however, version 21.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
from sagemaker.automl.automl import AutoML, AutoMLInput
import pyexasol
from io import BytesIO
from urllib.request import urlopen
import pandas as pd
from zipfile import ZipFile

# %%
EXASOL_HOST = "34.244.245.56" # change
EXASOL_PORT = "8563" # change if needed
EXASOL_USER = "sys" # change if needed
EXASOL_PASSWORD = "9UyIRRuYPYaxjeqb" #change
EXASOL_SCHEMA = "IDA"
tags = [{"Key":"exa:owner", "Value": "torsten.kilias@exasol.com"}]

# %%
EXASOL_CONNECTION = "{host}:{port}".format(host=EXASOL_HOST, port=EXASOL_PORT)
exasol = pyexasol.connect(dsn=EXASOL_CONNECTION, user=EXASOL_USER, password=EXASOL_PASSWORD, compression=True)

# %%
DATA_URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/00414/to_uci.zip"
TRAINING_FILE = "to_uci/aps_failure_training_set.csv"
TEST_FILE = "to_uci/aps_failure_test_set.csv"

# Data is preceeded with a 20-line header (copyright & license)
NUM_SKIP_ROWS = 20
NA_VALUE = "na"

resp = urlopen(DATA_URL)
with open('to_uci.zip', 'wb') as f:  
    f.write(resp.read())
    
print("data downloaded")
# Out:
# data downloaded

# %%
with ZipFile('to_uci.zip') as z:
    with z.open(TRAINING_FILE, "r") as f:
        train_set = pd.read_csv(f, skiprows=NUM_SKIP_ROWS, na_values=NA_VALUE)
    with z.open(TEST_FILE, "r") as f:
        test_set = pd.read_csv(f, skiprows=NUM_SKIP_ROWS, na_values=NA_VALUE)

# %%
exasol.execute(query="CREATE SCHEMA IF NOT EXISTS {schema!i}", query_params={"schema": EXASOL_SCHEMA})
# Out:
# <ExaStatement session_id=1707345019852750848 stmt_idx=2>

# %%
# Define column names and types
column_names = list(train_set.columns)
column_types = ["VARCHAR(3)"] + ["DECIMAL(18,2)"] * (len(column_names) - 1)
column_desc = [" ".join(t) for t in zip(column_names, column_types)]

params = {"schema": EXASOL_SCHEMA, "column_names": column_names, "column_desc": column_desc}

# Create tables for data
exasol.execute(query="CREATE OR REPLACE TABLE {schema!i}.TRAIN(" + ", ".join(column_desc) + ")", query_params=params)
exasol.execute(query="CREATE OR REPLACE TABLE {schema!i}.TEST LIKE {schema!i}.TRAIN", query_params=params)

# Import data into Exasol
exasol.import_from_pandas(train_set, (EXASOL_SCHEMA, "TRAIN"))
print(f"Imported {exasol.last_statement().rowcount()} rows into TRAIN.")
exasol.import_from_pandas(test_set, (EXASOL_SCHEMA, "TEST"))
print(f"Imported {exasol.last_statement().rowcount()} rows into TEST.")
# Out:
# Imported 60000 rows into TRAIN.
# Imported 16000 rows into TEST.

# %%
exasol.export_to_pandas("SELECT * FROM {schema!q}.TRAIN LIMIT 4",{"schema": EXASOL_SCHEMA})
# Out:
#   CLASS  AA_000  AB_000      AC_000  AD_000  AE_000  AF_000  AG_000  AG_001  \
# 0   neg   76698     NaN  2130706438   280.0       0       0       0       0
# 1   neg   33058     NaN           0     NaN       0       0       0       0
# 2   neg   41040     NaN         228   100.0       0       0       0       0
# 3   neg      12     0.0          70    66.0       0      10       0       0
#
#    AG_002  ...   EE_002  EE_003  EE_004  EE_005  EE_006  EE_007  EE_008  \
# 0       0  ...  1240520  493384  721044  469792  339156  157956   73224
# 1       0  ...   421400  178064  293306  245416  133654   81140   97576
# 2       0  ...   277378  159812  423992  409564  320746  158022   95128
# 3       0  ...      240      46      58      44      10       0       0
#
#    EE_009  EF_000  EG_000
# 0       0       0       0
# 1    1500       0       0
# 2     514       0       0
# 3       0       4      32
#
# [4 rows x 171 columns]

# %%
all_columns = exasol.export_to_pandas("SELECT * FROM {schema!q}.TRAIN LIMIT 1;", {"schema": EXASOL_SCHEMA})
column_names = list(all_columns)
column_names.remove("CLASS")
exasol.execute("""CREATE OR REPLACE TABLE {schema!q}.TRAIN_PREPARED AS (
               SELECT RANDOM() AS SPLIT,
               (CLASS = 'pos') as CLASS_POS, {all_columns_except_class!q} FROM {schema!q}.TRAIN)""",
               { "schema": EXASOL_SCHEMA, "all_columns_except_class": column_names})
# Out:
# <ExaStatement session_id=1707345019852750848 stmt_idx=9>

# %%
exasol.export_to_pandas("SELECT * FROM {schema!q}.TRAIN_PREPARED LIMIT 4", {"schema": EXASOL_SCHEMA})
# Out:
#       SPLIT  CLASS_POS  AA_000  AB_000  AC_000  AD_000  AE_000  AF_000  \
# 0  0.794572          0   41116     NaN       0     NaN       0       0
# 1  0.793678          0   59726     NaN      78    40.0       0       0
# 2  0.648744          0   30066     NaN     340   340.0       0       0
# 3  0.752580          0  125250     NaN       0     NaN       0       0
#
#    AG_000  AG_001  ...  EE_002  EE_003   EE_004   EE_005  EE_006  EE_007  \
# 0       0       0  ...  199780  101244   272518   433912  372908  163418
# 1       0       0  ...  340830  201640   583574   708870  582644  227474
# 2       0       0  ...  258204  129524   265784   294224  199650   91130
# 3       0       0  ...  794026  510006  1348866  1101396  825410  489878
#
#    EE_008  EE_009  EF_000  EG_000
# 0  195492   13496       0       0
# 1   70738      14       0       0
# 2  111416    3228       0       0
# 3  505230    5224       0       0
#
# [4 rows x 172 columns]

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker import image_uris
import boto

role = get_execution_role()
sess = sagemaker.Session()
bucket = sess.default_bucket()
bucket
# Out:
# 'sagemaker-eu-west-1-216764142018'

# %%
columns = exasol.export_to_pandas("SELECT * FROM {schema!q}.TRAIN_PREPARED LIMIT 1;", {"schema": EXASOL_SCHEMA})
column_names = list(columns)
column_names.remove("SPLIT") ## remove split column from select_list
parameters = {"all_columns_except_split": column_names, "schema": EXASOL_SCHEMA, "bucket": bucket}
exasol.execute("""EXPORT (SELECT {all_columns_except_split!q} FROM {schema!q}.TRAIN_PREPARED WHERE SPLIT <= 0.8)
                    INTO CSV AT 'https://{bucket!r}.s3.amazonaws.com'
                    USER '' IDENTIFIED BY '' FILE 'train/train.csv' WITH COLUMN NAMES;""", parameters)
exasol.execute("""EXPORT (SELECT {all_columns_except_split!q} FROM {schema!q}.TRAIN_PREPARED WHERE SPLIT > 0.8)
                    INTO CSV AT 'https://{bucket!r}.s3.amazonaws.com'
                    USER '' IDENTIFIED BY '' FILE 'validation/validation.csv' WITH COLUMN NAMES;""", parameters)
# Out:
# <ExaStatement session_id=1707345019852750848 stmt_idx=22>

# %%
from sagemaker import image_uris
from sagemaker.inputs import TrainingInput
from sagemaker.estimator import Estimator
from sagemaker.serializers import CSVSerializer
s3_input_train = TrainingInput(s3_data='s3://{}/train'.format(bucket), content_type='csv')
s3_input_validation = TrainingInput(s3_data='s3://{}/validation/'.format(bucket), content_type='csv')

container = image_uris.retrieve('xgboost', boto3.Session().region_name, '1.2-1' )
xgb = Estimator(container,
                role,
                instance_count=1,
                instance_type='ml.m4.xlarge',
                output_path='s3://{}/output'.format(bucket),
                tags = tags
               )

xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='binary:logistic',
                        num_round=100)

xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2021-08-06 12:19:13 Starting - Starting the training job...
# 2021-08-06 12:19:36 Starting - Launching requested ML instancesProfilerReport-1628252353: InProgress
# ......
# 2021-08-06 12:20:37 Starting - Preparing the instances for training......
# 2021-08-06 12:21:44 Downloading - Downloading input data...
# 2021-08-06 12:21:58 Training - Downloading the training image.....[2021-08-06 12:22:52.428 ip-10-0-100-78.eu-west-1.compute.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# INFO:root:Train matrix has 47788 rows and 170 columns
# INFO:root:Validation matrix has 12212 rows
# [0]#011train-error:0.00831#011validation-error:0.01114
# [1]#011train-error:0.00758#011validation-error:0.01040
# [2]#011train-error:0.00776#011validation-error:0.01015
# [3]#011train-error:0.00714#011validation-error:0.00983
# [4]#011train-error:0.00707#011validation-error:0.00933
# [5]#011train-error:0.00653#011validation-error:0.00909
# [6]#011train-error:0.00630#011validation-error:0.00893
# [7]#011train-error:0.00607#011validation-error:0.00868
# [8]#011train-error:0.00596#011validation-error:0.00868
#
# 2021-08-06 12:22:57 Training - Training image download completed. Training in progress.[9]#011train-error:0.00557#011validation-error:0.00860
# [10]#011train-error:0.00565#011validation-error:0.00860
# [11]#011train-error:0.00552#011validation-error:0.00860
# [12]#011train-error:0.00544#011validation-error:0.00811
# [13]#011train-error:0.00540#011validation-error:0.00802
# [14]#011train-error:0.00532#011validation-error:0.00770
# [15]#011train-error:0.00509#011validation-error:0.00770
# [16]#011train-error:0.00488#011validation-error:0.00770
# [17]#011train-error:0.00490#011validation-error:0.00753
# [18]#011train-error:0.00471#011validation-error:0.00762
# [19]#011train-error:0.00450#011validation-error:0.00770
# [20]#011train-error:0.00439#011validation-error:0.00737
# [21]#011train-error:0.00435#011validation-error:0.00745
# [22]#011train-error:0.00425#011validation-error:0.00745
# [23]#011train-error:0.00423#011validation-error:0.00753
# [24]#011train-error:0.00423#011validation-error:0.00762
# [25]#011train-error:0.00416#011validation-error:0.00712
# [26]#011train-error:0.00404#011validation-error:0.00712
# [27]#011train-error:0.00389#011validation-error:0.00696
# [28]#011train-error:0.00366#011validation-error:0.00712
# [29]#011train-error:0.00370#011validation-error:0.00680
# [30]#011train-error:0.00377#011validation-error:0.00696
# [31]#011train-error:0.00356#011validation-error:0.00663
# [32]#011train-error:0.00347#011validation-error:0.00663
# [33]#011train-error:0.00335#011validation-error:0.00655
# [34]#011train-error:0.00333#011validation-error:0.00663
# [35]#011train-error:0.00331#011validation-error:0.00680
# [36]#011train-error:0.00316#011validation-error:0.00671
# [37]#011train-error:0.00316#011validation-error:0.00671
# [38]#011train-error:0.00299#011validation-error:0.00680
# [39]#011train-error:0.00291#011validation-error:0.00688
# [40]#011train-error:0.00291#011validation-error:0.00688
# [41]#011train-error:0.00285#011validation-error:0.00704
# [42]#011train-error:0.00278#011validation-error:0.00729
# [43]#011train-error:0.00268#011validation-error:0.00712
# [44]#011train-error:0.00264#011validation-error:0.00688
# [45]#011train-error:0.00264#011validation-error:0.00688
# [46]#011train-error:0.00255#011validation-error:0.00688
# [47]#011train-error:0.00239#011validation-error:0.00696
# [48]#011train-error:0.00241#011validation-error:0.00680
# [49]#011train-error:0.00239#011validation-error:0.00663
# [50]#011train-error:0.00228#011validation-error:0.00688
# [51]#011train-error:0.00224#011validation-error:0.00696
# [52]#011train-error:0.00218#011validation-error:0.00671
# [53]#011train-error:0.00213#011validation-error:0.00663
# [54]#011train-error:0.00215#011validation-error:0.00655
# [55]#011train-error:0.00213#011validation-error:0.00680
# [56]#011train-error:0.00211#011validation-error:0.00655
# [57]#011train-error:0.00207#011validation-error:0.00663
# [58]#011train-error:0.00201#011validation-error:0.00671
# [59]#011train-error:0.00203#011validation-error:0.00671
# [60]#011train-error:0.00201#011validation-error:0.00663
# [61]#011train-error:0.00184#011validation-error:0.00688
# [62]#011train-error:0.00186#011validation-error:0.00688
# [63]#011train-error:0.00184#011validation-error:0.00671
# [64]#011train-error:0.00182#011validation-error:0.00655
# [65]#011train-error:0.00178#011validation-error:0.00647
# [66]#011train-error:0.00176#011validation-error:0.00647
# [67]#011train-error:0.00176#011validation-error:0.00655
# [68]#011train-error:0.00174#011validation-error:0.00663
# [69]#011train-error:0.00169#011validation-error:0.00655
# [70]#011train-error:0.00169#011validation-error:0.00655
# [71]#011train-error:0.00169#011validation-error:0.00630
# [72]#011train-error:0.00165#011validation-error:0.00639
# [73]#011train-error:0.00165#011validation-error:0.00639
# [74]#011train-error:0.00167#011validation-error:0.00639
# [75]#011train-error:0.00161#011validation-error:0.00655
# [76]#011train-error:0.00163#011validation-error:0.00647
# [77]#011train-error:0.00163#011validation-error:0.00647
# [78]#011train-error:0.00157#011validation-error:0.00639
# [79]#011train-error:0.00155#011validation-error:0.00639
#
# 2021-08-06 12:23:40 Uploading - Uploading generated training model[80]#011train-error:0.00157#011validation-error:0.00639
# [81]#011train-error:0.00155#011validation-error:0.00639
# [82]#011train-error:0.00155#011validation-error:0.00630
# [83]#011train-error:0.00155#011validation-error:0.00630
# [84]#011train-error:0.00155#011validation-error:0.00630
# [85]#011train-error:0.00159#011validation-error:0.00647
# [86]#011train-error:0.00159#011validation-error:0.00647
# [87]#011train-error:0.00151#011validation-error:0.00647
# [88]#011train-error:0.00146#011validation-error:0.00630
# [89]#011train-error:0.00151#011validation-error:0.00630
# [90]#011train-error:0.00144#011validation-error:0.00647
# [91]#011train-error:0.00144#011validation-error:0.00647
# [92]#011train-error:0.00144#011validation-error:0.00655
# [93]#011train-error:0.00142#011validation-error:0.00663
# [94]#011train-error:0.00138#011validation-error:0.00655
# [95]#011train-error:0.00128#011validation-error:0.00663
# [96]#011train-error:0.00128#011validation-error:0.00655
# [97]#011train-error:0.00123#011validation-error:0.00655
# [98]#011train-error:0.00123#011validation-error:0.00655
# [99]#011train-error:0.00123#011validation-error:0.00655
#
# 2021-08-06 12:23:57 Completed - Training job completed
# ProfilerReport-1628252353: NoIssuesFound
# Training seconds: 125
# Billable seconds: 125

# %%
s3_train_path='s3://{}/train'.format(bucket)
automl_job=AutoML(role=role,
                  target_attribute_name="CLASS_POS",
                  max_candidates=10)
s3_input_train = AutoMLInput(inputs=s3_train_path,target_attribute_name="CLASS_POS")

# %%
s3 = boto3.client('s3')
s3_object=s3.download_file(bucket,"train/train.csv","train.csv")

# %%
automl_job.fit(inputs=s3_input_train)
# Out:
# ...................................................................................................................................................................................................................................................
